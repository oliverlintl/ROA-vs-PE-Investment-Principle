# %% [markdown]
# # ROA vs. P/E Investment Evaluation
#
# ### Overarching Principle:
# > Finding stocks that are undervalued.
#
# To do so, we refer to the method used by Joel Greenblat in his book The Little Book That Beats the Market.
# We will use ***Return on Asset*** (ROA) to reflect how profitable a company is, and we will use ***Trailing Price-To-Earnings*** (Trailing PE) to find out if a stock is a relative bargain compare to other stocks.
#
# Note: This method cannot identify growth stock, since it does not take into considertaion of a company's future.

# %%
# !pip install fix-yahoo-finance==0.1.3
# !pip install yfinance==0.1.70
# Out:
# Requirement already satisfied: yfinance==0.1.70 in /usr/local/lib/python3.7/dist-packages (0.1.70)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance==0.1.70) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance==0.1.70) (1.21.5)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance==0.1.70) (0.0.10)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance==0.1.70) (2.27.1)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance==0.1.70) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance==0.1.70) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance==0.1.70) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance==0.1.70) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance==0.1.70) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance==0.1.70) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance==0.1.70) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance==0.1.70) (1.24.3)

# %%
import yfinance as yf   # for getting information from yahoo finance
# yfinance use reference: https://towardsdatascience.com/financial-data-from-yahoo-finance-with-python-b5399743bcc6
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
from pandas.core.apply import Apply
# test getting data
tick = yf.Ticker('MRNA')
print(tick.info)
print(tick.info['open'])
print(tick.info.get('trailingPE'))
print(tick.info['trailingEps'])
print(tick.info['returnOnAssets'])
# print(tick.info['open']/tick.info['trailingEps'])
# Out:
# {'zip': '02139', 'sector': 'Healthcare', 'fullTimeEmployees': 3000, 'longBusinessSummary': 'Moderna, Inc., a biotechnology company, develops therapeutics and vaccines based on messenger RNA for the treatment of infectious diseases, immuno-oncology, rare diseases, cardiovascular diseases, and auto-immune diseases. As of March 9, 2021, the company had 13 programs in clinical trials and a total of 24 development programs in six modalities comprising prophylactic vaccines, cancer vaccines, intratumoral immuno-oncology, localized regenerative therapeutics, systemic secreted and cell surface therapeutics, and systemic intracellular therapeutics. The company has strategic alliances with AstraZeneca PLC, Merck & Co., Inc., Vertex Pharmaceuticals Incorporated, Vertex Pharmaceuticals (Europe) Limited, the Biomedical Advanced Research and Development Authority, the Defense Advanced Research Projects Agency, the National Institute of Allergy and Infectious Diseases, the National Institutes of Health, the Coalition for Epidemic Preparedness Innovations, Metagenomi, Inc., and Bill & Melinda Gates Foundation. Moderna, Inc. also has collaborations with Lonza Ltd.; Catalent Inc., Laboratorios Farmac̩uticos Rovi, S.A., Recipharm, and Lonza Group; Aldevron, LLC; Institute for Life Changing Medicines; and AbCellera Biologics Inc. The company was formerly known as Moderna Therapeutics, Inc. and changed its name to Moderna, Inc. in August 2018. Moderna, Inc. was founded in 2010 and is headquartered in Cambridge, Massachusetts.', 'city': 'Cambridge', 'phone': '617 714 6500', 'state': 'MA', 'country': 'United States', 'companyOfficers': [], 'website': 'https://www.modernatx.com', 'maxAge': 1, 'address1': '200 Technology Square', 'fax': '617 583 1998', 'industry': 'Biotechnology', 'ebitdaMargins': 0.73095, 'profitMargins': 0.66059995, 'grossMargins': 0.85832, 'operatingCashflow': None, 'revenueGrowth': 11.634, 'operatingMargins': 0.71983004, 'ebitda': 13501333504, 'targetLowPrice': 81, 'recommendationKey': 'buy', 'grossProfits': 15854000000, 'freeCashflow': None, 'targetMedianPrice': 210.17, 'currentPrice': 151.33, 'earningsGrowth': None, 'currentRatio': None, 'returnOnAssets': None, 'numberOfAnalystOpinions': 17, 'targetMeanPrice': 250.3, 'debtToEquity': 5.758, 'returnOnEquity': 1.92379, 'targetHighPrice': 506, 'totalCash': 8906000384, 'totalDebt': 583000000, 'totalRevenue': 18471000064, 'totalCashPerShare': 21.966, 'financialCurrency': 'USD', 'revenuePerShare': 45.834, 'quickRatio': None, 'recommendationMean': 2.5, 'exchange': 'NMS', 'shortName': 'Moderna, Inc.', 'longName': 'Moderna, Inc.', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EST', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '-18000000', 'quoteType': 'EQUITY', 'symbol': 'MRNA', 'messageBoardId': 'finmb_128680956', 'market': 'us_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 2.979, 'beta3Year': None, 'enterpriseToEbitda': 4.075, '52WeekChange': -0.038564146, 'morningStarRiskRating': None, 'forwardEps': 11.62, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 405449984, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'totalAssets': None, 'bookValue': 24.998, 'sharesShort': 16028740, 'sharesPercentSharesOut': 0.0395, 'fundFamily': None, 'lastFiscalYearEnd': 1640908800, 'heldPercentInstitutions': 0.62031, 'netIncomeToCommon': 12202000384, 'trailingEps': 28.29, 'lastDividendValue': None, 'SandP52WeekChange': 0.123744845, 'priceToBook': 6.0536847, 'heldPercentInsiders': 0.09316, 'nextFiscalYearEnd': 1703980800, 'yield': None, 'mostRecentQuarter': 1640908800, 'shortRatio': 1.63, 'sharesShortPreviousMonthDate': 1640908800, 'floatShares': 367523778, 'beta': None, 'enterpriseValue': 55020380160, 'priceHint': 2, 'threeYearAverageReturn': None, 'lastSplitDate': None, 'lastSplitFactor': None, 'legalType': None, 'lastDividendDate': None, 'morningStarOverallRating': None, 'earningsQuarterlyGrowth': None, 'priceToSalesTrailing12Months':  ...
# 156.02
# 5.34924
# 28.29
# None

# %% [markdown]
# ## Start the model building

# %%
# get list of stocks wished to compare
# ticker_list = ['SBUX', 'F', 'OXY']
ticker_list = ['SBUX', 'OXY', 'AAPL', 'MSFT', 'TSLA', 'DIS', 'AMD', 'GOOGL', 'QCOM', 'SONY', 'PLUG', 'TGT', 'MCD', 
               'INTC', 'BAC', 'BA', 'F', 'AMZN', 'NFLX', 'HPQ', 'BABA', 'DAL', 'GS', 'JPM', 'WMT', 'FB', 'UAA',
               'PLNT', 'BILI', 'JBLU', 'XOM', 'JNJ']

# %%
# create empty dataframe
df = pd.DataFrame(columns = ['Ticker', 'ROA', 'TrailingPE'])
print(df)
# Out:
# Empty DataFrame
# Columns: [Ticker, ROA, TrailingPE]
# Index: []

# %%
from numpy import NaN
for ticker in ticker_list:
  # adding ticker object
  tick_info = yf.Ticker(ticker)
  # getting ROA
  ROA = tick_info.info.get('returnOnAssets')
  # getting trailing PE
  try:
    trailingPE = tick_info.info.get('trailingPE')
  except KeyError:
    print('Trailing PE not found for', ticker + '.', 'Calculating using opening price divided by trailing EPS')
    trailingPE = tick_info.info.get('open')/tick_info.info.get('trailingEps')
  if trailingPE is None:
    trailingPE = NaN
    print('Trailing PE of', ticker, 'is less than 0, use NaN as value')
  # create dictionary for this ticker
  ticker_info = pd.DataFrame({'Ticker': [ticker], 'ROA': [ROA], 'TrailingPE': [trailingPE]})
  # update dataframe
  df = df.append(ticker_info)
# Out:
# Trailing PE of PLUG is less than 0, use NaN as value
# Trailing PE of BA is less than 0, use NaN as value
# Trailing PE of DAL is less than 0, use NaN as value
# Trailing PE of BILI is less than 0, use NaN as value
# Trailing PE of JBLU is less than 0, use NaN as value
# Trailing PE of XOM is less than 0, use NaN as value

# %%
df.reset_index(drop=True, inplace = True)
df.head()
# Out:
#   Ticker      ROA  TrailingPE
# 0   SBUX  0.10477   25.014862
# 1    OXY  0.04048   24.518988
# 2   AAPL  0.19875   27.406485
# 3   MSFT  0.15249   31.665780
# 4   TSLA  0.07135  165.245860

# %% [markdown]
# ## Add rank to dataframe

# %%
df['ROA Rank'] = df['ROA'].rank(ascending = False)
df['Trailing PE Rank'] = df['TrailingPE'].rank(na_option = 'bottom')
df['Value Points'] = df['ROA Rank'] + df['Trailing PE Rank']
df['Overall Rank'] = df['Value Points'].rank()
df
# Out:
#    Ticker      ROA  TrailingPE  ...  Trailing PE Rank  Value Points  Overall Rank
# 0    SBUX  0.10477   25.014862  ...              17.0          25.0          12.0
# 1     OXY  0.04048   24.518988  ...              14.0          35.0          20.5
# 2    AAPL  0.19875   27.406485  ...              18.0          20.0           7.0
# 3    MSFT  0.15249   31.665780  ...              20.0          25.0          12.0
# 4    TSLA  0.07135  165.245860  ...              26.0          40.0          23.5
# 5     DIS  0.01690   88.847300  ...              24.0          49.0          27.0
# 6     AMD  0.21327   47.105057  ...              22.0          23.0           9.5
# 7   GOOGL  0.14493   23.968466  ...              13.0          19.0           6.0
# 8    QCOM  0.17321   19.588585  ...              10.0          14.0           3.0
# 9    SONY  0.02392   15.291611  ...               9.0          32.0          18.5
# 10   PLUG -0.12046         NaN  ...              29.5          61.5          32.0
# 11    TGT  0.10204   14.662545  ...               6.0          15.0           4.0
# 12    MCD  0.11490   24.855518  ...              15.0          22.0           8.0
# 13   INTC  0.08586    9.816872  ...               4.0          17.0           5.0
# 14    BAC  0.01068   13.479042  ...               5.0          32.0          18.5
# 15     BA -0.00217         NaN  ...              29.5          57.5          28.0
# 16      F  0.02524   25.007013  ...              16.0          38.0          22.0
# 17   AMZN  0.05321   60.192370  ...              23.0          40.0          23.5
# 18   NFLX  0.10012   35.235780  ...              21.0          31.0          17.0
# 19    HPQ  0.09911    6.463415  ...               2.0          13.0           2.0
# 20   BABA  0.04238   15.166503  ...               8.0          28.0          15.0
# 21    DAL -0.03502         NaN  ...              29.5          58.5          29.0
# 22     GS  0.01724    5.774699  ...               1.0          25.0          12.0
# 23    JPM  0.01356    9.633464  ...               3.0          29.0          16.0
# 24    WMT  0.06520   28.004108  ...              19.0          35.0          20.5
# 25     FB  0.18568   15.062258  ...               7.0          10.0           1.0
# 26    UAA  0.06577   23.064936  ...              12.0          27.0          14.0
# 27   PLNT  0.04941  157.257770  ...              25.0          44.0          25.0
# 28   BILI -0.09977         NaN  ...              29.5          60.5          31.0
# 29   JBLU -0.06022         NaN  ...              29.5          59.5          30.0
# 30    XOM  0.04984         NaN  ...              29.5          47.5          26.0
# 31    JNJ  0.08842   21.254800  ...              11.0          23.0           9.5
#
# [32 rows x 7 columns]

# %% [markdown]
# ## Visualize ROA and PE

# %%
# use plotly to create interactive scatterplot for ROA vs Trailing PE
# https://plotly.com/python/line-and-scatter/
fig = px.scatter(df, x = 'ROA', y = 'TrailingPE', color = 'Ticker', text = 'Ticker', title = 'ROA vs Trailing PE Plot')
fig.update_traces(marker_size = 15)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="baf21a69-99ea-49ea-b4e7-64d8656336a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("baf21a69-99ea-49ea-b4e7-64d8656336a2")) {                    Plotly.newPlot(                        "baf21a69-99ea-49ea-b4e7-64d8656336a2",                        [{"hovertemplate":"Ticker=%{text}<br>ROA=%{x}<br>TrailingPE=%{y}<extra></extra>","legendgroup":"SBUX","marker":{"color":"#636efa","symbol":"circle","size":15},"mode":"markers+text","name":"SBUX","orientation":"v","showlegend":true,"text":["SBUX"],"x":[0.104770005],"xaxis":"x","y":[25.014862],"yaxis":"y","type":"scatter"},{"hovertemplate":"Ticker=%{text}<br>ROA=%{x}<br>TrailingPE=%{y}<extra></extra>","legendgroup":"OXY","marker":{"color":"#EF553B","symbol":"circle","size":15},"mode":"markers+text","name":"OXY","orientation":"v","showlegend":true,"text":["OXY"],"x":[0.04048],"xaxis":"x","y":[24.518988],"yaxis":"y","type":"scatter"},{"hovertemplate":"Ticker=%{text}<br>ROA=%{x}<br>TrailingPE=%{y}<extra></extra>","legendgroup":"AAPL","marker":{"color":"#00cc96","symbol":"circle","size":15},"mode":"markers+text","name":"AAPL","orientation":"v","showlegend":true,"text":["AAPL"],"x":[0.19875],"xaxis":"x","y":[27.406485],"yaxis":"y","type":"scatter"},{"hovertemplate":"Ticker=%{text}<br>ROA=%{x}<br>TrailingPE=%{y}<extra></extra>","legendgroup":"MSFT","marker":{"color":"#ab63fa","symbol":"circle","size":15},"mode":"markers+text","name":"MSFT","orientation":"v","showlegend":true,"text":["MSFT"],"x":[0.15248999],"xaxis":"x","y":[31.66578],"yaxis":"y","type":"scatter"},{"hovertemplate":"Ticker=%{text}<br>ROA=%{x}<br>TrailingPE=%{y}<extra></extra>","legendgroup":"TSLA","marker":{"color":"#FFA15A","symbol":"circle","size":15},"mode":"markers+text","name":"TSLA","orientation":"v","showlegend":true,"text":["TSLA"],"x":[0.07135],"xaxis":"x","y":[165.24586],"yaxis":"y","type":"scatter"},{"hovertemplate":"Ticker=%{text}<br>ROA=%{x}<br>TrailingPE=%{y}<extra></extra>","legendgroup":"DIS","marker":{"color":"#19d3f3","symbol":"circle","size":15},"mode":"markers+text","name":"DIS","orientation":"v","showlegend":true,"text":["DIS"],"x":[0.016900001],"xaxis":"x","y":[88.8473],"yaxis":"y","type":"scatter"},{"hovertemplate":"Ticker=%{text}<br>ROA=%{x}<br>TrailingPE=%{y}<extra></extra>","legendgroup":"AMD","marker":{"color":"#FF6692","symbol":"circle","size":15},"mode":"markers+text","name":"AMD","orientation":"v","showlegend":true,"text":["AMD"],"x":[0.21327],"xaxis":"x","y":[47.105057],"yaxis":"y","type":"scatter"},{"hovertemplate":"Ticker=%{text}<br>ROA=%{x}<br>TrailingPE=%{y}<extra></extra>","legendgroup":"GOOGL","marker":{"color":"#B6E880","symbol":"circle","size":15},"mode":"markers+text","name":"GOOGL","orientation":"v","showlegend":true,"text":["GOOGL"],"x":[0.14493],"xaxis":"x","y":[23.968466],"yaxis":"y","type":"scatter"},{"hovertemplate":"Ticker=%{text}<br>ROA=%{x}<br>TrailingPE=%{y}<extra></extra>","legendgroup":"QCOM","marker":{"color":"#FF97FF","symbol":"circle","size":15},"mode":"markers+text","name":"QCOM","orientation":"v","showlegend":true,"text":["QCOM"],"x":[0.17321],"xaxis":"x","y":[19.588585],"yaxis":"y","type":"scatter"},{"hovertemplate":"Ticker=%{text}<br>ROA=%{x}<br>TrailingPE=%{y}<extra></extra>","legendgroup":"SONY","marker":{"color":"#FECB52","symbol":"circle","size":15},"mode":"markers+text","name":"SONY","orientation":"v","showlegend":true,"text":["SONY"],"x":[0.02392],"xaxis":"x","y":[15.291611],"yaxis":"y","type":"scatter"},{"hovertemplate":"Ticker=%{text}<br>ROA=%{x}<br>TrailingPE=%{y}<extra></extra>","legendgroup":"PLUG","marker":{"color":"#636efa","symbol":"circle","size":15},"mode":"markers+text","name":"PLUG","orientation":"v","showlegend":true,"text":["PLUG"],"x":[-0.120459996],"xaxis ...

# %%
# plot ROA rank
df_roa = df.sort_values(by='ROA Rank', ascending = False)
px.bar(df_roa, x = 'ROA Rank', y = 'Ticker', orientation = 'h', title = 'Ranking by ROA', hover_data=["ROA"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c562f8da-a381-41d6-942f-bc1f15ccf4d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c562f8da-a381-41d6-942f-bc1f15ccf4d9")) {                    Plotly.newPlot(                        "c562f8da-a381-41d6-942f-bc1f15ccf4d9",                        [{"alignmentgroup":"True","customdata":[[-0.120459996],[-0.09977],[-0.06022],[-0.03502],[-0.00217],[0.010679999],[0.01356],[0.016900001],[0.017239999],[0.02392],[0.025239998],[0.04048],[0.042379998],[0.04941],[0.049840003],[0.05321],[0.0652],[0.06577],[0.07135],[0.08586001],[0.08842],[0.09911],[0.10012],[0.10204001],[0.104770005],[0.1149],[0.14493],[0.15248999],[0.17321],[0.18568],[0.19875],[0.21327]],"hovertemplate":"ROA Rank=%{x}<br>Ticker=%{y}<br>ROA=%{customdata[0]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[32.0,31.0,30.0,29.0,28.0,27.0,26.0,25.0,24.0,23.0,22.0,21.0,20.0,19.0,18.0,17.0,16.0,15.0,14.0,13.0,12.0,11.0,10.0,9.0,8.0,7.0,6.0,5.0,4.0,3.0,2.0,1.0],"xaxis":"x","y":["PLUG","BILI","JBLU","DAL","BA","BAC","JPM","DIS","GS","SONY","F","OXY","BABA","PLNT","XOM","AMZN","WMT","UAA","TSLA","INTC","JNJ","HPQ","NFLX","TGT","SBUX","MCD","GOOGL","MSFT","QCOM","FB","AAPL","AMD"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d" ...

# %%
# plot Trailing PE rank
df_roa = df.sort_values(by='Trailing PE Rank', ascending = False)
px.bar(df_roa, x = 'Trailing PE Rank', y = 'Ticker', orientation = 'h', title = 'Ranking by Trailing PE', hover_data=["TrailingPE"])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="404ce12c-fcdf-42c4-b21e-e79732909444" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("404ce12c-fcdf-42c4-b21e-e79732909444")) {                    Plotly.newPlot(                        "404ce12c-fcdf-42c4-b21e-e79732909444",                        [{"alignmentgroup":"True","customdata":[[null],[null],[null],[null],[null],[null],[165.24586],[157.25777],[88.8473],[60.19237],[47.105057],[35.23578],[31.66578],[28.004108],[27.406485],[25.014862],[25.007013],[24.855518],[24.518988],[23.968466],[23.064936],[21.2548],[19.588585],[15.291611],[15.166503],[15.062258],[14.662545],[13.479042],[9.816872],[9.633464],[6.4634147],[5.7746987]],"hovertemplate":"Trailing PE Rank=%{x}<br>Ticker=%{y}<br>TrailingPE=%{customdata[0]}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[29.5,29.5,29.5,29.5,29.5,29.5,26.0,25.0,24.0,23.0,22.0,21.0,20.0,19.0,18.0,17.0,16.0,15.0,14.0,13.0,12.0,11.0,10.0,9.0,8.0,7.0,6.0,5.0,4.0,3.0,2.0,1.0],"xaxis":"x","y":["XOM","JBLU","BILI","PLUG","DAL","BA","TSLA","PLNT","DIS","AMZN","AMD","NFLX","MSFT","WMT","AAPL","SBUX","F","MCD","OXY","GOOGL","UAA","JNJ","QCOM","SONY","BABA","FB","TGT","BAC","INTC","JPM","HPQ","GS"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}]," ...

# %%
# plot Trailing overall rank
df_roa = df.sort_values(by='Overall Rank', ascending = False)
px.bar(df_roa, x = 'Overall Rank', y = 'Ticker', orientation = 'h', title = 'Overall Ranking')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a18fcc9b-4f04-47d8-8067-fa3c5fbf940c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a18fcc9b-4f04-47d8-8067-fa3c5fbf940c")) {                    Plotly.newPlot(                        "a18fcc9b-4f04-47d8-8067-fa3c5fbf940c",                        [{"alignmentgroup":"True","hovertemplate":"Overall Rank=%{x}<br>Ticker=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[32.0,31.0,30.0,29.0,28.0,27.0,26.0,25.0,23.5,23.5,22.0,20.5,20.5,18.5,18.5,17.0,16.0,15.0,14.0,12.0,12.0,12.0,9.5,9.5,8.0,7.0,6.0,5.0,4.0,3.0,2.0,1.0],"xaxis":"x","y":["PLUG","BILI","JBLU","DAL","BA","DIS","XOM","PLNT","TSLA","AMZN","F","WMT","OXY","SONY","BAC","NFLX","JPM","BABA","UAA","GS","SBUX","MSFT","AMD","JNJ","MCD","AAPL","GOOGL","INTC","TGT","QCOM","HPQ","FB"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d" ...
